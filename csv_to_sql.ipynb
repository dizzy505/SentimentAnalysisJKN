# %%
import pandas as pd
from sqlalchemy import create_engine

# 1. Bikin koneksi ke MySQL
engine = create_engine('mysql+pymysql://root:localicad@localhost:3306/world_layoffs')

# 2. Baca data dari tabel
df = pd.read_sql('SELECT * FROM layoffs_staging2', con=engine)

# 3. Export ke CSV
df.to_csv('layoffs_output.csv', index=False)
